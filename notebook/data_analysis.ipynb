# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore", UserWarning)

from scipy.stats import chi2_contingency
from sklearn.feature_selection import mutual_info_classif

os.chdir('..')

# %%
from data.utils import get_stock_df
from feature.label import compute_labels
from config.config import buy_sell_signals, label_names, feature_names

# %%
def load_data_file(csv_file):
    if not os.path.exists(csv_file):
        raise FileNotFoundError(
            f"Please run data_fetcher.py to download the data first.")
    else:
        df = pd.read_csv(csv_file)
        df['Date'] = pd.to_datetime(df['Date'])
        df.set_index('Date', inplace=True)
    return df

start_date = "2023-04-01"
end_date = "2025-03-31"
csv_file = f"./data/dataset/stock_training_{start_date}_{end_date}.csv"
df_all = load_data_file(csv_file)

# %%
stocks = df_all['stock'].unique()

df_corr = None
for i, stock in enumerate(stocks):
    print(">>>>>>stock: ", stock)
    df = get_stock_df(df_all, stock)
    # create labels and add them into the dataframe
    df, daily_change_perc = compute_labels(df)
    if df_corr is None:
        df_corr = df[buy_sell_signals + label_names + ["stock"]]
    else:
        df = df[buy_sell_signals + label_names + ["stock"]]
        df_corr = pd.concat([df_corr, df], axis=0)

df_corr = df_corr.dropna()
# Out:
# >>>>>>stock:  HD
# >>>>>>stock:  MTB
# >>>>>>stock:  SLB
# >>>>>>stock:  CZR
# >>>>>>stock:  MELI
# >>>>>>stock:  CHD
# >>>>>>stock:  ULTA
# >>>>>>stock:  DGX
# >>>>>>stock:  PLTR
# >>>>>>stock:  FDS
# >>>>>>stock:  MAR
# >>>>>>stock:  STE
# >>>>>>stock:  CHRW
# >>>>>>stock:  DOW
# >>>>>>stock:  HLT
# >>>>>>stock:  AMZN
# >>>>>>stock:  ADI
# >>>>>>stock:  CSX
# >>>>>>stock:  EXE
# >>>>>>stock:  K
# >>>>>>stock:  KR
# >>>>>>stock:  INTU
# >>>>>>stock:  PYPL
# >>>>>>stock:  ATO
# >>>>>>stock:  MU
# >>>>>>stock:  FRT
# >>>>>>stock:  APD
# >>>>>>stock:  DLR
# >>>>>>stock:  ADBE
# >>>>>>stock:  GEV
# >>>>>>stock:  HUM
# >>>>>>stock:  EBAY
# >>>>>>stock:  WAT
# >>>>>>stock:  SW
# >>>>>>stock:  EMN
# >>>>>>stock:  UHS
# >>>>>>stock:  WST
# >>>>>>stock:  APTV
# >>>>>>stock:  ALGN
# >>>>>>stock:  DUK
# >>>>>>stock:  BX
# >>>>>>stock:  BLK
# >>>>>>stock:  DD
# >>>>>>stock:  EG
# >>>>>>stock:  AZO
# >>>>>>stock:  EVRG
# >>>>>>stock:  ELV
# >>>>>>stock:  MNST
# >>>>>>stock:  WSM
# >>>>>>stock:  HSY
# >>>>>>stock:  PCG
# >>>>>>stock:  GILD
# >>>>>>stock:  IR
# >>>>>>stock:  GPC
# >>>>>>stock:  VLTO
# >>>>>>stock:  META
# >>>>>>stock:  TRV
# >>>>>>stock:  DHR
# >>>>>>stock:  UDR
# >>>>>>stock:  AXON
# >>>>>>stock:  BDX
# >>>>>>stock:  TFC
# >>>>>>stock:  GOOG
# >>>>>>stock:  FE
# >>>>>>stock:  FSLR
# >>>>>>stock:  MOH
# >>>>>>stock:  NVR
# >>>>>>stock:  F
# >>>>>>stock:  EQT
# >>>>>>stock:  ABT
# >>>>>>stock:  LMT
# >>>>>>stock:  RJF
# >>>>>>stock:  MKC
# >>>>>>stock:  URI
# >>>>>>stock:  NDAQ
# >>>>>>stock:  LIN
# >>>>>>stock:  CINF
# >>>>>>stock:  CNP
# >>>>>>stock:  LHX
# >>>>>>stock:  LOW
# >>>>>>stock:  TT
# >>>>>>stock:  CDW
# >>>>>>stock:  NKE
# >>>>>>stock:  PSA
# >>>>>>stock:  GDDY
# >>>>>>stock:  REGN
# >>>>>>stock:  PKG
# >>>>>>stock:  XEL
# >>>>>>stock:  TSCO
# >>>>>>stock:  ADSK
# >>>>>>stock:  ACN
# >>>>>>stock:  LEN
# >>>>>>stock:  NSC
# >>>>>>stock:  MAS
# >>>>>>stock:  JPM
# >>>>>>stock:  OKE
# >>>>>>stock:  SBAC
# >>>>>>stock:  CME
# >>>>>>stock:  WDC
# >>>>>>stock:  VICI
# >>>>>>stock:  AMD
# >>>>>>stock:  CAG
# >>>>>>stock:  NVDA
# >>>>>>stock:  PFE
# >>>>>>stock:  HES
# >>>>>>stock:  TRMB
# >>>>>>stock:  CI
# >>>>>>stock:  WFC
# >>>>>>stock:  NEM
# >>>>>>stock:  DXCM
# >>>>>>stock:  DAY
# >>>>>>stock:  IP
# >>>>>>stock:  LYV
# >>>>>>stock:  FOX
# >>>>>>stock:  PARA
# >>>>>>stock:  GL
# >>>>>>stock:  CCI
# >>>>>>stock:  TER
# >>>>>>stock:  MTCH
# >>>>>>stock:  V
# >>>>>>stock:  YUM
# >>>>>>stock:  MPC
# >>>>>>stock:  APH
# >>>>>>stock:  CF
# >>>>>>stock:  BMY
# >>>>>>stock:  COF
# >>>>>>stock:  ORCL
# >>>>>>stock:  ETN
# >>>>>>stock:  BRO
# >>>>>>stock:  CHTR
# >>>>>>stock:  BG
# >>>>>>stock:  EPAM
# >>>>>>stock:  CEG
# >>>>>>stock:  DOV
# >>>>>>stock:  EL
# >>>>>>stock:  DAL
# >>>>>>stock:  JBL
# >>>>>>stock:  ROP
# >>>>>>stock:  ROL
# >>>>>>stock:  IQV
# >>>>>>stock:  EA
# >>>>>>stock:  ABBV
# >>>>>>stock:  AJG
# >>>>>>stock:  NDSN
# >>>>>>stock:  TECH
# >>>>>>stock:  C
# >>>>>>stock:  PPL
# >>>>>>stock:  MRVL
# >>>>>>stock:  FTV
# >>>>>>stock:  WYNN
# >>>>>>stock:  DVN
# >>>>>>stock:  UAL
# >>>>>>stock:  BKR
# >>>>>>stock:  EXPE
# >>>>>>stock:  DDOG
# >>>>>>stock:  DLTR
# >>>>>>stock:  EXC
# >>>>>>stock:  SO
# >>>>>>stock:  MKTX
# >>>>>>stock:  ED
# >>>>>>stock:  TMO
# >>>>>>stock:  TPL
# >>>>>>stock:  MGM
# >>>>>>stock:  VRTX
# >>>>>>stock:  DOC
# >>>>>>stock:  KMI
# >>>>>>stock:  IEX
# >>>>>>stock:  GM
# >>>>>>stock:  EQR
# >>>>>>stock:  SJM
# >>>>>>stock:  AIZ
# >>>>>>stock:  TYL
# >>>>>>stock:  ALB
# >>>>>>stock:  DASH
# >>>>>>stock:  IT
# >>>>>>stock:  TSN
# >>>>>>stock:  PEG
# >>>>>>stock:  RL
# >>>>>>stock:  MET
# >>>>>>stock:  DRI
# >>>>>>stock:  MDLZ
# >>>>>>stock:  IDXX
# >>>>>>stock:  NCLH
# >>>>>>stock:  HCA
# >>>>>>stock:  GPN
# >>>>>>stock:  SYF
# >>>>>>stock:  AES
# >>>>>>stock:  BAC
# >>>>>>stock:  BXP
# >>>>>>stock:  HST
# >>>>>>stock:  APO
# >>>>>>stock:  PM
# >>>>>>stock:  TTWO
# >>>>>>stock:  RVTY
# >>>>>>stock:  KDP
# >>>>>>stock:  FCX
# >>>>>>stock:  EW
# >>>>>>stock:  HPE
# >>>>>>stock:  PHM
# >>>>>>stock:  SYY
# >>>>>>stock:  FTNT
# >>>>>>stock:  JNPR
# >>>>>>stock:  CMCSA
# >>>>>>stock:  OMC
# >>>>>>stock:  JBHT
# >>>>>>stock:  GLW
# >>>>>>stock:  IFF
# >>>>>>stock:  LRCX
# >>>>>>stock:  MSFT
# >>>>>>stock:  NFLX
# >>>>>>stock:  LKQ
# >>>>>>stock:  XOM
# >>>>>>stock:  ARE
# >>>>>>stock:  BEN
# >>>>>>stock:  FI
# >>>>>>stock:  TAP
# >>>>>>stock:  VTRS
# >>>>>>stock:  VTR
# >>>>>>stock:  ROK
# >>>>>>stock:  REG
# >>>>>>stock:  AEE
# >>>>>>stock:  INCY
# >>>>>>stock:  DHI
# >>>>>>stock:  PDD
# >>>>>>stock:  HWM
# >>>>>>stock:  GEN
# >>>>>>stock:  CPRT
# >>>>>>stock:  AKAM
# >>>>>>stock:  HAS
# >>>>>>stock:  NUE
# >>>>>>stock:  CSCO
# >>>>>>stock:  PGR
# >>>>>>stock:  PODD
# >>>>>>stock:  LUV
# >>>>>>stock:  WAB
# >>>>>>stock:  ZTS
# >>>>>>stock:  SYK
# >>>>>>stock:  PANW
# >>>>>>stock:  PLD
# >>>>>>stock:  WY
# >>>>>>stock:  AME
# >>>>>>stock:  WEC
# >>>>>>stock:  LNT
# >>>>>>stock:  CCL
# >>>>>>stock:  OXY
# >>>>>>stock:  CMS
# >>>>>>stock:  WMB
# >>>>>>stock:  ZS
# >>>>>>stock:  MLM
# >>>>>>stock:  EOG
# >>>>>>stock:  UBER
# >>>>>>stock:  WDAY
# >>>>>>stock:  SRE
# >>>>>>stock:  GWW
# >>>>>>stock:  SWK
# >>>>>>stock:  GIS
# >>>>>>stock:  LVS
# >>>>>>stock:  SOLV
# >>>>>>stock:  GS
# >>>>>>stock:  TXN
# >>>>>>stock:  AVY
# >>>>>>stock:  CL
# >>>>>>stock:  GFS
# >>>>>>stock:  JNJ
# >>>>>>stock:  CTVA
# >>>>>>stock:  IBM
# >>>>>>stock:  BLDR
# >>>>>>stock:  COR
# >>>>>>stock:  MCK
# >>>>>>stock:  TTD
# >>>>>>stock:  CTAS
# >>>>>>stock:  JCI
# >>>>>>stock:  KMX
# >>>>>>stock:  EQIX
# >>>>>>stock:  PTC
# >>>>>>stock:  AON
# >>>>>>stock:  VRSN
# >>>>>>stock:  AMT
# >>>>>>stock:  SHW
# >>>>>>stock:  VLO
# >>>>>>stock:  PAYC
# >>>>>>stock:  PWR
# >>>>>>stock:  ADP
# >>>>>>stock:  ES
# >>>>>>stock:  NWSA
# >>>>>>stock:  CRL
# >>>>>>stock:  PG
# >>>>>>stock:  HOLX
# >>>>>>stock:  JKHY
# >>>>>>stock:  HBAN
# >>>>>>stock:  SBUX
# >>>>>>stock:  VMC
# >>>>>>stock:  EFX
# >>>>>>stock:  CMI
# >>>>>>stock:  MO
# >>>>>>stock:  PNR
# >>>>>>stock:  TDY
# >>>>>>stock:  NTRS
# >>>>>>stock:  PH
# >>>>>>stock:  CCEP
# >>>>>>stock:  ZBRA
# >>>>>>stock:  ICE
# >>>>>>stock:  BKNG
# >>>>>>stock:  BK
# >>>>>>stock:  KHC
# >>>>>>stock:  TDG
# >>>>>>stock:  INTC
# >>>>>>stock:  ARM
# >>>>>>stock:  SWKS
# >>>>>>stock:  POOL
# >>>>>>stock:  CTSH
# >>>>>>stock:  AMP
# >>>>>>stock:  CTRA
# >>>>>>stock:  ECL
# >>>>>>stock:  PAYX
# >>>>>>stock:  TJX
# >>>>>>stock:  ADM
# >>>>>>stock:  ZBH
# >>>>>>stock:  EMR
# >>>>>>stock:  MCHP
# >>>>>>stock:  A
# >>>>>>stock:  KEYS
# >>>>>>stock:  KMB
# >>>>>>stock:  CBOE
# >>>>>>stock:  FFIV
# >>>>>>stock:  ON
# >>>>>>stock:  WBA
# >>>>>>stock:  SCHW
# >>>>>>stock:  MSI
# >>>>>>stock:  RMD
# >>>>>>stock:  DVA
# >>>>>>stock:  MMC
# >>>>>>stock:  BA
# >>>>>>stock:  IVZ
# >>>>>>stock:  CFG
# >>>>>>stock:  ISRG
# >>>>>>stock:  PEP
# >>>>>>stock:  AAPL
# >>>>>>stock:  STT
# >>>>>>stock:  CAT
# >>>>>>stock:  HAL
# >>>>>>stock:  TKO
# >>>>>>stock:  BAX
# >>>>>>stock:  UNP
# >>>>>>stock:  MRK
# >>>>>>stock:  SNA
# >>>>>>stock:  TRGP
# >>>>>>stock:  BBY
# >>>>>>stock:  ODFL
# >>>>>>stock:  ACGL
# >>>>>>stock:  LDOS
# >>>>>>stock:  D
# >>>>>>stock:  KEY
# >>>>>>stock:  HUBB
# >>>>>>stock:  SMCI
# >>>>>>stock:  FITB
# >>>>>>stock:  FOXA
# >>>>>>stock:  ANET
# >>>>>>stock:  MCD
# >>>>>>stock:  UPS
# >>>>>>stock:  NOC
# >>>>>>stock:  USB
# >>>>>>stock:  TGT
# >>>>>>stock:  CAH
# >>>>>>stock:  BALL
# >>>>>>stock:  AMAT
# >>>>>>stock:  AVB
# >>>>>>stock:  IPG
# >>>>>>stock:  J
# >>>>>>stock:  BR
# >>>>>>stock:  RF
# >>>>>>stock:  TEL
# >>>>>>stock:  GE
# >>>>>>stock:  LW
# >>>>>>stock:  GRMN
# >>>>>>stock:  LYB
# >>>>>>stock:  DE
# >>>>>>stock:  KLAC
# >>>>>>stock:  WBD
# >>>>>>stock:  CVX
# >>>>>>stock:  TSLA
# >>>>>>stock:  BSX
# >>>>>>stock:  HPQ
# >>>>>>stock:  MRNA
# >>>>>>stock:  GD
# >>>>>>stock:  IRM
# >>>>>>stock:  MSTR
# >>>>>>stock:  RCL
# >>>>>>stock:  QCOM
# >>>>>>stock:  OTIS
# >>>>>>stock:  LLY
# >>>>>>stock:  COP
# >>>>>>stock:  ANSS
# >>>>>>stock:  DFS
# >>>>>>stock:  GEHC
# >>>>>>stock:  EIX
# >>>>>>stock:  WMT
# >>>>>>stock:  CRWD
# >>>>>>stock:  AMGN
# >>>>>>stock:  PSX
# >>>>>>stock:  PPG
# >>>>>>stock:  ENPH
# >>>>>>stock:  NRG
# >>>>>>stock:  VST
# >>>>>>stock:  LH
# >>>>>>stock:  NTAP
# >>>>>>stock:  MPWR
# >>>>>>stock:  DG
# >>>>>>stock:  STZ
# >>>>>>stock:  HSIC
# >>>>>>stock:  SPGI
# >>>>>>stock:  CVS

# %%
# Cramér’s V
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    return np.sqrt(phi2 / min(k - 1, r - 1))

for col in buy_sell_signals:
    score = cramers_v(df_corr[col], df_corr["trend_10days"])
    print(f"{col}: {score:.3f}")
# Out:
# MA_5_20_Crossover_Signal: 0.156
# MA_5_10_Crossover_Signal: 0.194
# MA_5_50_Crossover_Signal: 0.116
# MA_10_20_Crossover_Signal: 0.121
# MA_20_50_Crossover_Signal: 0.070
# MACD_Crossover_Signal: 0.196
# VWAP_Crossover_Signal: 0.111

# %%
# Mutual Information
X = df_corr[buy_sell_signals]
y = df_corr["trend_10days"]

mi_scores = mutual_info_classif(X, y, discrete_features=True)

for feature, score in zip(X.columns, mi_scores):
    print(f"{feature}: {score:.3f}")
# Out:
# MA_5_20_Crossover_Signal: 0.012
# MA_5_10_Crossover_Signal: 0.019
# MA_5_50_Crossover_Signal: 0.007
# MA_10_20_Crossover_Signal: 0.007
# MA_20_50_Crossover_Signal: 0.003
# MACD_Crossover_Signal: 0.018
# VWAP_Crossover_Signal: 0.006

# %%
# Group Frequency Tables
for col in df_corr[buy_sell_signals]:
    print(f"\n=== {col} ===")
    print(pd.crosstab(df_corr[col], df_corr["trend_10days"], normalize="index"))
# Out:
# === MA_5_20_Crossover_Signal ===
# trend_10days                   0.0       1.0       2.0
# MA_5_20_Crossover_Signal
# -1                        0.854661  0.002534  0.142805
#  0                        0.959012  0.023192  0.017796
#  1                        0.823108  0.175606  0.001286
#
# === MA_5_10_Crossover_Signal ===
# trend_10days                   0.0       1.0       2.0
# MA_5_10_Crossover_Signal
# -1                        0.866307  0.006124  0.127569
#  0                        0.964336  0.019799  0.015865
#  1                        0.824541  0.172142  0.003316
#
# === MA_5_50_Crossover_Signal ===
# trend_10days                   0.0       1.0       2.0
# MA_5_50_Crossover_Signal
# -1                        0.856291  0.003311  0.140397
#  0                        0.955748  0.024871  0.019381
#  1                        0.817851  0.181157  0.000992
#
# === MA_10_20_Crossover_Signal ===
# trend_10days                    0.0       1.0       2.0
# MA_10_20_Crossover_Signal
# -1                         0.857201  0.015798  0.127000
#  0                         0.957392  0.024174  0.018434
#  1                         0.845522  0.145627  0.008851
#
# === MA_20_50_Crossover_Signal ===
# trend_10days                    0.0       1.0       2.0
# MA_20_50_Crossover_Signal
# -1                         0.887374  0.020202  0.092424
#  0                         0.953892  0.025719  0.020388
#  1                         0.830483  0.157948  0.011569
#
# === MACD_Crossover_Signal ===
# trend_10days                0.0       1.0       2.0
# MACD_Crossover_Signal
# -1                     0.850594  0.000859  0.148546
#  0                     0.962253  0.021111  0.016636
#  1                     0.797555  0.201426  0.001019
#
# === VWAP_Crossover_Signal ===
# trend_10days                0.0       1.0       2.0
# VWAP_Crossover_Signal
# -1                     0.852014  0.006781  0.141205
#  0                     0.955397  0.024992  0.019610
#  1                     0.803997  0.190623  0.005380
